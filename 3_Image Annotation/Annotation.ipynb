# %%
import os
import cv2
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

from zipfile import ZipFile
from urllib.request import urlretrieve

matplotlib.rcParams['figure.figsize'] = (9.0, 9.0)
# %matplotlib inline

# %%
def download_and_unzip(url, save_path):
    print(f"Downloading and extracting assests....", end="")

    # Downloading zip file using urllib package.
    urlretrieve(url, save_path)

    try:
        # Extracting zip file using the zipfile package.
        with ZipFile(save_path) as z:
            # Extract ZIP file contents in the same directory.
            z.extractall(os.path.split(save_path)[0])

        print("Done")

    except Exception as e:
        print("\nInvalid file.", e)

# %%
URL = r"https://www.dropbox.com/s/48hboi1m4crv1tl/opencv_bootcamp_assets_NB3.zip?dl=1"

asset_zip_path = os.path.join(os.getcwd(), f"opencv_bootcamp_assets_NB3.zip")

# Download if assest ZIP does not exists. 
if not os.path.exists(asset_zip_path):
    download_and_unzip(URL, asset_zip_path)

# %%
Apollo  = cv2.imread('Apollo_11_Launch.jpg',1)
plt.imshow(Apollo[:,:,::-1]);plt.show()

# %% [markdown]
# #### Drawing a line
#
# img = cv2.line(img,pt1,pt2, color[, thickness[, lineType[, shift]]])
# 1. img - input image
# 2. pt1 - First point location
# 3. pt2 - Second point of line
# 4. Color - Line color
#
# Optional arguments
# 1. thickness
# 2. lineType

# %%
ApolloLine = Apollo.copy()
pt1 = (200,100) #start
pt2 = (400,100) #end
color = (0,255,0) #green

cv2.line(ApolloLine, pt1, pt2, color, thickness=5, lineType=cv2.LINE_AA)
plt.imshow(ApolloLine[:,:,::-1]);plt.show()

# %% [markdown]
# #### Drawing a circle
#
# img = cv2.circle(img, center, radius, color[, thickness[, lineType[, shift]]])
#
# 1. center -center of circle
# 2. Radius
#
# optional arguments
# 1. Thickness
# 2. Shift

# %%
ApolloCircle = Apollo.copy()
center = (300,300)
radius = 100
color = (255,0,0) #BGR
thickness = 5 #negative thickness will fill the circle

cv2.circle(ApolloCircle, center, radius, color, thickness, lineType=cv2.LINE_AA)
plt.imshow(ApolloCircle[:,:,::-1]);plt.show()

# %% [markdown]
# #### Drawing a Rectangle
# 1. pt1 - Top left of the rectangle
# 2. pt2 - Bottom right of the rectangle

# %%
ApolloRectangle = Apollo.copy()
pt1 = (500,100)
pt2 = (700,600)
color = (255,0,255) 
thickness = 5

cv2.rectangle(ApolloRectangle, pt1, pt2, color, thickness, lineType=cv2.LINE_AA)
plt.imshow(ApolloRectangle[:,:,::-1]);plt.show()

# %% [markdown]
# #### Adding text
#
# img = cv2.putText(img, text, org, fontFace, fontScale, color[, thickness[, lineType[, bottomLeftOrigin]]])
#
# 1. text - string
# 2. org - Bottom left corner of the text
# 3. fontFace - type
# 4. fontScale - size

# %%
ApolloText = Apollo.copy()
text = 'Apollo 11 Saturn V Launch  July 16, 1969'
fontScale = 2.3
fontFace = cv2.FONT_HERSHEY_PLAIN
fontColor = (0, 255, 0)
fontThickness = 2

cv2.putText(ApolloText, text, (200, 700), fontFace, fontScale, fontColor, fontThickness, cv2.LINE_AA)
plt.imshow(ApolloText[:,:,::-1]);plt.show()
